# %%
import numpy as np
import pandas as pd
url ="https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
iris= pd.read_csv(url)
print(iris)
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
iris.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
pd.columns=['sepal_length','sepal_width','petal_length','petal_width','class']
print(pd.columns)
for header in pd.columns:
  print (header)
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
# sepal_length
# sepal_width
# petal_length
# petal_width
# class

# %% [markdown]
# to check if any missing values.

# %%
print(iris.isnull().values.any())
# Out:
# False

# %% [markdown]
#  Write a code to set the values of the rows 10 to 29 of the column 'petal_length' to NaN.

# %%
iris.loc[10:29, 'petal_length'] = np.nan
print(iris.loc[10:29,'petal_length'])
# Out:
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# Name: petal_length, dtype: float64

# %%
print(iris.isnull().values.any())
print(iris.isnull().sum())
# Out:
# True
# 5.1               0
# 3.5               0
# 1.4               0
# 0.2               0
# Iris-setosa       0
# petal_length    149
# dtype: int64

# %%
print(iris.isnull().sum().sum())
# Out:
# 149

# %%
iris.fillna(10.0, inplace=True)
print(iris.isnull().sum())
# Out:
# 5.1             0
# 3.5             0
# 1.4             0
# 0.2             0
# Iris-setosa     0
# petal_length    0
# dtype: int64
